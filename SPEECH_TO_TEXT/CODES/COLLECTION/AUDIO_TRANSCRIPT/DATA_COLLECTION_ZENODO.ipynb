# %% [markdown]
# # SETUP

# %%
# %%capture
# !pip install fastapi kaleido python-multipart uvicorn
# !pip install --upgrade datasets
# !pip install pandas pydub
# !pip install --upgrade librosa scipy soundfile

# %%
from datasets import load_dataset
import numpy as np
import pandas as pd
from pydub import AudioSegment
import wave
import os
import io
import librosa
from scipy.signal import resample as scipy_resample

# %%
path = r"C:\Users\maron\OneDrive\02-Documents\03.PROJETS\00.INFORMATIQUE\02.AI\WOLOF"
os.chdir(path)

# %% [markdown]
# # Functions

# %%
def resample_audio(input_path, path_audio):
    # Load the audio file
    try:
        audio, sr = librosa.load(path_audio + input_path, sr=None)

        # Calculate the duration of the original audio
        audio_duration = librosa.get_duration(y=audio, sr=sr)

        del audio
        del sr

        return audio_duration
    except:
        print('ERROR: failed to read:  ' + input_path )
        return None

# %%
def resample_audio_(input_path, path_audio, target_sr=16000):
    # Load the audio file
    audio, sr = librosa.load(path_audio + input_path, sr=None)

    # Resample to 16 kHz
    audio_resampled = librosa.resample(audio, orig_sr=sr, target_sr=target_sr)

    del audio
    del sr

    return audio_resampled

# %%
def rename_path_to_path_complet(row, path, ext):
    return path + '\\' + row + ext

# %% [markdown]
# # Data loading

# %% [markdown]
# ## common voice

# %%
voiceweb_clips = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\tsv\voiceweb_clips.tsv", sep = "\t")
voiceweb_clips.head(2).T
# Out:
#                                                                       0  \
# id                                                                    1
# client_id                          4af26658-5f2a-401c-aa35-748717079afa
# path                  4af26658-5f2a-401c-aa35-748717079afa/02d98c90f...
# sentence              "Tey texeg ndaw ñi,ak mag ñi,ak waxambaane yee...
# original_sentence_id  02d98c90f6950423ebb7f25f436480e84c6baf149ab036...
# created_at                                          2020-09-15 17:45:30
# bucket                                                            train
# locale_id                                                             2
# needs_votes                                                           1
# is_valid                                                            NaN
# validated_at                                                        NaN
#
#                                                                       1
# id                                                                    2
# client_id                          4af26658-5f2a-401c-aa35-748717079afa
# path                  4af26658-5f2a-401c-aa35-748717079afa/038677fc2...
# sentence                                                Jamonoy cëtëŋ j
# original_sentence_id  038677fc2a6c36b549322f47fdd083a51a58e220ab10d8...
# created_at                                          2020-09-15 17:45:31
# bucket                                                            train
# locale_id                                                             2
# needs_votes                                                           1
# is_valid                                                            1.0
# validated_at                                                 2020-09-18

# %%
voiceweb_sentence = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\tsv\voiceweb_sentences.tsv", sep = "\t")
voiceweb_sentence.head(2).T
# Out:
#                                                                 0  \
# id              0000dd0a940305d48c1bf2852f333629cb9db6b9e73d89...
# text                                        Mbaa yaa ngi am jàmm.
# is_used                                                         1
# created_at                                    2020-09-15 15:59:02
# bucket                                                      train
# locale_id                                                       2
# clips_count                                                     2
# version                                                         1
# source                             fr_data_to_be_recorded_for_tts
# has_valid_clip                                                  0
#
#                                                                 1
# id              0002480565c93f8619bb3d2f5f0af22613530552af2b8e...
# text                                             Ndax solu ngeen?
# is_used                                                         1
# created_at                                    2020-09-15 15:59:03
# bucket                                                      train
# locale_id                                                       2
# clips_count                                                     2
# version                                                         1
# source                             fr_data_to_be_recorded_for_tts
# has_valid_clip                                                  0

# %%
voiceweb_sentence = voiceweb_sentence.dropna(subset=['text'])

# %% [markdown]
# ## Female voices

# %%
female_test = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\female_test.tsv", sep = "\t")
female_train = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\female_train.tsv", sep = "\t")
female_validation = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\female_valdiation.tsv", sep = "\t")

dataframes = [female_train, female_validation, female_test]
female = pd.concat(dataframes, axis=0, ignore_index=True)
female.head(2).T
# Out:
#                                                                       0  \
# id                                                                 5599
# client_id                          fbc2f100-357a-4840-b1df-8b562861e8dd
# path                  data-commonvoice/audios/fbc2f100-357a-4840-b1d...
# sentence                                      Nanga moytu jegeñante bi.
# original_sentence_id  2627b1b38d06bf257a22a85ea67e240f9b43db39d4eba2...
# created_at                                          2020-12-03 14:19:02
# bucket                                                            train
# locale_id                                                             2
# needs_votes                                                           1
# is_valid                                                            NaN
# validated_at                                                        NaN
# caracter_count                                                       25
# word_count                                                            4
#
#                                                                       1
# id                                                                 5600
# client_id                          fbc2f100-357a-4840-b1df-8b562861e8dd
# path                  data-commonvoice/audios/fbc2f100-357a-4840-b1d...
# sentence                          Asi rekk la taqalool ci yeneen gox yi
# original_sentence_id  2a048ddc15edf6bf932ad8b9ba0a4018866f79ae17f9ba...
# created_at                                          2020-12-03 14:19:03
# bucket                                                            train
# locale_id                                                             2
# needs_votes                                                           1
# is_valid                                                            NaN
# validated_at                                                        NaN
# caracter_count                                                       37
# word_count                                                            8

# %%
female_red = female.drop(columns = ['is_valid', 'needs_votes', 'needs_votes', 'locale_id', 'bucket', 'created_at', 'validated_at', 'client_id'])
female_red.head(2).T
# Out:
#                                                                       0  \
# id                                                                 5599
# path                  data-commonvoice/audios/fbc2f100-357a-4840-b1d...
# sentence                                      Nanga moytu jegeñante bi.
# original_sentence_id  2627b1b38d06bf257a22a85ea67e240f9b43db39d4eba2...
# caracter_count                                                       25
# word_count                                                            4
#
#                                                                       1
# id                                                                 5600
# path                  data-commonvoice/audios/fbc2f100-357a-4840-b1d...
# sentence                          Asi rekk la taqalool ci yeneen gox yi
# original_sentence_id  2a048ddc15edf6bf932ad8b9ba0a4018866f79ae17f9ba...
# caracter_count                                                       37
# word_count                                                            8

# %% [markdown]
# ## Male voice

# %%
male_test = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\male_test.tsv", sep = "\t")
male_train = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\male_train.tsv", sep = "\t")
male_validation = pd.read_csv(r"SPEECH_TO_TEXT\DATA\BRUT\WOLOF_AUDIO_TRANS\zenodo\male_validation.tsv", sep = "\t")

dataframes = [male_train, male_validation, male_test]
male = pd.concat(dataframes, axis=0, ignore_index=True)
male.head(2).T
# Out:
#                                                                       0  \
# id                                                                 4080
# client_id                          ba524146-26b0-4d13-81fd-5a16547d9ce3
# path                  data-commonvoice/audios/ba524146-26b0-4d13-81f...
# sentence                 Te boo wooteeb xeex ñu néew ñoo la ciy fekksi.
# original_sentence_id  1fea98a25ffdfda32850ef55825f81834c8810ba2357ea...
# created_at                                          2020-12-02 09:09:09
# bucket                                                            train
# locale_id                                                             2
# needs_votes                                                           1
# is_valid                                                            NaN
# validated_at                                                        NaN
# caracter_count                                                       46
# word_count                                                           10
#
#                                                                       1
# id                                                                 4082
# client_id                          ba524146-26b0-4d13-81fd-5a16547d9ce3
# path                  data-commonvoice/audios/ba524146-26b0-4d13-81f...
# sentence                                      Ñëw leen ci waat yii boog
# original_sentence_id  19e9b3b644e6a8bd0c470e2e71a1d4da1a8d37ec6007d5...
# created_at                                          2020-12-02 09:09:11
# bucket                                                            train
# locale_id                                                             2
# needs_votes                                                           1
# is_valid                                                            NaN
# validated_at                                                        NaN
# caracter_count                                                       25
# word_count                                                            6

# %%
male_red = male.drop(columns = ['is_valid', 'needs_votes', 'needs_votes', 'locale_id', 'bucket', 'created_at', 'validated_at', 'client_id'])
male_red.head(2).T
# Out:
#                                                                       0  \
# id                                                                 4080
# path                  data-commonvoice/audios/ba524146-26b0-4d13-81f...
# sentence                 Te boo wooteeb xeex ñu néew ñoo la ciy fekksi.
# original_sentence_id  1fea98a25ffdfda32850ef55825f81834c8810ba2357ea...
# caracter_count                                                       46
# word_count                                                           10
#
#                                                                       1
# id                                                                 4082
# path                  data-commonvoice/audios/ba524146-26b0-4d13-81f...
# sentence                                      Ñëw leen ci waat yii boog
# original_sentence_id  19e9b3b644e6a8bd0c470e2e71a1d4da1a8d37ec6007d5...
# caracter_count                                                       25
# word_count                                                            6

# %% [markdown]
# # Data preparation

# %%
zenodo = pd.DataFrame()

merged_df = voiceweb_clips.merge(voiceweb_sentence, left_on='original_sentence_id', right_on='id')

zenodo['transcription'] = merged_df['text']
zenodo['filename'] = merged_df['path']

zenodo.head(2).T
# Out:
#                                                                0  \
# transcription  "Tey texeg ndaw ñi,ak mag ñi,ak waxambaane yee...
# filename       4af26658-5f2a-401c-aa35-748717079afa/02d98c90f...
#
#                                                                1
# transcription  "Tey texeg ndaw ñi,ak mag ñi,ak waxambaane yee...
# filename       fbc2f100-357a-4840-b1df-8b562861e8dd/02d98c90f...

# %%
import IPython.display as ipd
import random

rand_int = random.randint(0, len(zenodo)-1)

ipd.Audio(data = resample_audio_(zenodo["filename"].iloc[rand_int], r"SPEECH_TO_TEXT\DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio\\"), autoplay = True, rate = 16000)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(zenodo["transcription"].iloc[rand_int])
# Out:
# Wax naa la nga génn.

# %%
zenodo.to_csv(r"SPEECH_TO_TEXT\DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\zenodo_cleaned.csv")

# %%
zenodo['path'] = zenodo['filename'].apply(lambda row: rename_path_to_path_complet(row, r"DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio", ext=''))
zenodo.head(1).T
# Out:
#                                                                0
# transcription  "Tey texeg ndaw ñi,ak mag ñi,ak waxambaane yee...
# filename       4af26658-5f2a-401c-aa35-748717079afa/02d98c90f...
# path           DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio\4a...

# %% [markdown]
# # Final cleaned data

# %%
path_audio = r"SPEECH_TO_TEXT\DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio\\"
zenodo['length'] = zenodo['filename'].apply(lambda row: resample_audio(row, path_audio))
zenodo.head(3).T
# Out:
# C:\Users\maron\AppData\Local\Temp\ipykernel_10948\45758396.py:4: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(path_audio + input_path, sr=None)
# c:\Users\maron\anaconda3\Lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ERROR: failed to read:  29f41f59-63cd-4220-82b0-3d6796fca217/029d11b55186a36cea1c3fea6e7a21e7f0e94d3526c014c6b8cb132f3f3a5131.mp3
# ERROR: failed to read:  29f41f59-63cd-4220-82b0-3d6796fca217/107951bdcd76285969c6e74dd044b4b601c654ee14b26b1b3f35930261b1db66.mp3
# ERROR: failed to read:  29f41f59-63cd-4220-82b0-3d6796fca217/11ea1a103a00a3adc7d7c4b0a2a8936124c77704c274c9e3d9c89b919cebf45e.mp3
# ERROR: failed to read:  29f41f59-63cd-4220-82b0-3d6796fca217/1155f5caea70cb67398589896f16b3cc896ffe05dc8ce79a9019dddf0fbed7eb.mp3
# ERROR: failed to read:  29f41f59-63cd-4220-82b0-3d6796fca217/0e646c55c474410a9d5d21b2c2f709c381bc6479925706fcf75e2a24349dcd74.mp3
# ERROR: failed to read:  ba524146-26b0-4d13-81fd-5a16547d9ce3/2f6296b54fb86357419db29d817932d18fef59316aa84391a01ee7a88c813f71.mp3
# ERROR: failed to read:  ba524146-26b0-4d13-81fd-5a16547d9ce3/5ca5045d353d1b2c0955418161248287d49551a77507d3019d022b41a6e03101.mp3
# ERROR: failed to read:  ba524146-26b0-4d13-81fd-5a16547d9ce3/5ef51a52f3f105505103c286123beffe58ff07f40b854980502d96e09599731a.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/78ee4c7ee972a74907aa3aa679a05986c1b162433a2a54691ad14aa5130bb5dc.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/6483fa871569084183fd58dc2569eda05c78ddc96be7baca239c1a8000b08065.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/74d8aa892cf6afeb7a9381debb76dabe435431b3169310391ee6d5f12be6c76b.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/7a2d34ebfa0681b9e5efe07adc32a3e8be5b24c4148fbc3b37eec8a015f4a50e.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/770f680cc728c9f39094b9b85de3c75048429a6181d7eac3758350673b34c788.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/77a1f7a6b462d6cec35369c36ce5bc712c804e61f4f71185ac57416f54427b16.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/7a229acaa6ae79838ae907454a6a624584141d7a12ba9ca093e7adf23ba7b9fc.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/7cb40f00d5b2041bd8186475050193bf1b925cbb08658b86a0a9f32e69f0e43e.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/7c092805c90f5ea4c0952cd2bf3229009a6b86577fd0adcadc44d5a78c73c4ae.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/741916b696ef1263c7e20cd34aceeca5b8514d7f7597ee4213e77e0807e4d614.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/711bae1677328b624da40dd648c6410d1c2432989fa9348bfb35ce3c0045850c.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/6f78d02d2e1db8d0a431712484a167706c59a87c444c4a6febd07496b71c4fde.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/73b2bbaf3f5c46f94c14bade83572ec8b08aac417109797d2fd609eda7b403af.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/642ebc87998b537890f55dbd20322310ce7ddc81f630afd0dfa47e2b038eb64a.mp3
# ERROR: failed to read:  fbc2f100-357a-4840-b1df-8b562861e8dd/39a67bc1f4863fb9bf2b812e72971d95a5cd8607c11eaa20a0e8c9d61a25bc68.mp3
#                                                                0  \
# transcription  "Tey texeg ndaw ñi,ak mag ñi,ak waxambaane yee...
# filename       4af26658-5f2a-401c-aa35-748717079afa/02d98c90f...
# path           DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio\4a...
# length                                                     6.384
#
#                                                                1  \
# transcription  "Tey texeg ndaw ñi,ak mag ñi,ak waxambaane yee...
# filename       fbc2f100-357a-4840-b1df-8b562861e8dd/02d98c90f...
# path           DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio\fb...
# length                                                     5.616
#
#                                                                2
# transcription                                    Jamonoy cëtëŋ j
# filename       4af26658-5f2a-401c-aa35-748717079afa/038677fc2...
# path           DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\audio\4a...
# length                                                     3.744

# %%
zenodo = zenodo.dropna(subset=['length'])

# %%
print(sum(zenodo['length']))
# Out:
# 163136.7146122475

# %%
def clean_text(row):
    return row.rstrip('"').lstrip('"')

# %%
zenodo['transcription'] = zenodo['transcription'].apply(clean_text)

# %%
zenodo.to_csv(r"SPEECH_TO_TEXT\DATA\CLEANED\WOLOF_AUDIO_TRANS\zenodo\zenodo_cleaned.csv")
